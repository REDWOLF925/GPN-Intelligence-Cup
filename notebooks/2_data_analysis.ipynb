# %% [markdown]
# ## **Анализ данных**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Загрузка данных

# %%
cases = pd.read_csv('../data/cases_labeled.csv', sep=';')
print(cases.columns.to_list())
cases.head()
# Out:
# ['Номер поручения', 'Заказчик', 'Дата поручения', 'Выполнено', 'Дата выполнения', 'Затрачено дней', 'Сумма вознаграждения', 'Описание', 'Тип поручения']
#    Номер поручения Заказчик Дата поручения Выполнено Дата выполнения  \
# 0            11000     Анна     1051-08-11        да      1051-08-21
# 1            11001    Мария     1051-07-09        да      1051-09-02
# 2            11002   Эмилио     1053-10-05        да      1053-10-20
# 3            11003   Бьянка     1052-11-24        да      1052-12-02
# 4            11004   Бьянка     1052-02-23        да      1052-03-30
#
#    Затрачено дней  Сумма вознаграждения  \
# 0             4.0                  6000
# 1             2.0                 20000
# 2             7.0                 22500
# 3             5.0                  5500
# 4             8.0                 10500
#
#                                             Описание  Тип поручения
# 0  В лесу по дороге от пещеры звери нападают на л...              3
# 1  В лесу по дороге от пещеры были замечены разбо...              3
# 2  По дороге из деревни монстры похитили путников...              1
# 3  Недалеко от города видели монстров. Нужно побе...              3
# 4  В деревне у меня пропала сумка с документами. ...              2

# %%
marks = pd.read_csv('../data/marks.csv', sep=';')
print(marks.columns.to_list())
marks.head()
# Out:
# ['Номер поручения', 'Герой', 'Оценка за качество', 'Оценка по срокам', 'Оценка за вежливость']
#    Номер поручения    Герой  Оценка за качество  Оценка по срокам  \
# 0            11000   Мартин                   4                 3
# 1            11001  Альфред                   5                 5
# 2            11002   Мартин                   5                 4
# 3            11003   Бендер                   2                 4
# 4            11004     Юлия                   4                 4
#
#    Оценка за вежливость
# 0                     4
# 1                     4
# 2                     4
# 3                     3
# 4                     5

# %%
diaries = pd.read_csv('../data/diaries.csv', sep=';')
diaries['Затрачено часов'] = diaries['Затрачено часов'].str.replace(',', '.').astype(float)
print(diaries.columns.to_list())
diaries.head()
# Out:
# ['Номер поручения', 'Герой', 'Запись в дневнике', 'Затрачено часов', 'Роль']
#    Номер поручения    Герой Запись в дневнике  Затрачено часов      Роль
# 0            11000   Мартин    разжечь костёр              1.0  рейнджер
# 1            11000   Мартин    выследить цель              6.0  следопыт
# 2            11001  Альфред    разжечь костёр              1.0  рейнджер
# 3            11001  Альфред     залечить раны             18.0    лекарь
# 4            11002   Мартин    выследить цель              6.0  следопыт

# %%
print('Всего выполненных поручений каждого типа:')
cases.loc[cases['Выполнено'] == 'да']['Тип поручения'].value_counts()
# Out:
# Всего выполненных поручений каждого типа:
# Тип поручения
# 3    161
# 2    148
# 0    110
# 1     62
# Name: count, dtype: int64

# %%
note_types = diaries['Запись в дневнике'].unique()
print('Все виды записей в дневнике:')
print(*note_types, sep=', ')
print()

class_to_type = {0:'Чудовище в пещере',
                 1:'Спасение путников',
                 2:'Поиск пропажи',
                 3:'монстры/разбойники'
                 }

for note in note_types:
    ids = diaries.loc[diaries['Запись в дневнике'] == note]['Номер поручения']
    texts = cases.loc[cases['Номер поручения'].isin(ids)]['Тип поручения'].value_counts().to_dict()
    print(f'"{note}" встречается в {len(texts)} типах поручений:')
    for key in texts:
        print(f'В заказе на "{class_to_type[key]}"({key}) встречается {texts[key]} раз')
    print()

print('=' * 50 + '\n')

role_types = diaries['Роль'].unique()
print('Все виды ролей:')
print(*role_types, sep=', ')
print()

class_to_role = {i:[] for i in range(4)}

for role in role_types:
    ids = diaries.loc[diaries['Роль'] == role]['Номер поручения']
    texts = cases.loc[cases['Номер поручения'].isin(ids)]['Тип поручения'].value_counts().to_dict()
    print(f'"{role}" встречается в {len(texts)} типах поручений:')
    for key in texts:
        class_to_role[key].append(role)
        print(f'В заказе на "{class_to_type[key]}"({key}) встречается {texts[key]} раз')
    print()

print('=' * 50 + '\n')
print(diaries[['Запись в дневнике', 'Роль']].groupby('Запись в дневнике').value_counts())
# Out:
# Все виды записей в дневнике:
# разжечь костёр, выследить цель, залечить раны, найти пропажу, отыскать заказчика
#
# "разжечь костёр" встречается в 2 типах поручений:
# В заказе на "монстры/разбойники"(3) встречается 161 раз
# В заказе на "Чудовище в пещере"(0) встречается 110 раз
#
# "выследить цель" встречается в 2 типах поручений:
# В заказе на "Спасение путников"(1) встречается 62 раз
# В заказе на "монстры/разбойники"(3) встречается 23 раз
#
# "залечить раны" встречается в 2 типах поручений:
# В заказе на "Чудовище в пещере"(0) встречается 63 раз
# В заказе на "монстры/разбойники"(3) встречается 58 раз
#
# "найти пропажу" встречается в 1 типах поручений:
# В заказе на "Поиск пропажи"(2) встречается 148 раз
#
# "отыскать заказчика" встречается в 1 типах поручений:
# В заказе на "Поиск пропажи"(2) встречается 148 раз
#
# ==================================================
#
# Все виды ролей:
# рейнджер, следопыт, лекарь, лучник, мечник, боевой маг
#
# "рейнджер" встречается в 1 типах поручений:
# В заказе на "монстры/разбойники"(3) встречается 115 раз
#
# "следопыт" встречается в 3 типах поручений:
# В заказе на "Поиск пропажи"(2) встречается 148 раз
# В заказе на "Спасение путников"(1) встречается 62 раз
# В заказе на "монстры/разбойники"(3) встречается 23 раз
#
# "лекарь" встречается в 2 типах поручений:
# В заказе на "Чудовище в пещере"(0) встречается 63 раз
# В заказе на "монстры/разбойники"(3) встречается 58 раз
#
# "лучник" встречается в 2 типах поручений:
# В заказе на "монстры/разбойники"(3) встречается 32 раз
# В заказе на "Чудовище в пещере"(0) встречается 23 раз
#
# "мечник" встречается в 2 типах поручений:
# В заказе на "монстры/разбойники"(3) встречается 106 раз
# В заказе на "Чудовище в пещере"(0) встречается 66 раз
#
# "боевой маг" встречается в 2 типах поручений:
# В заказе на "монстры/разбойники"(3) встречается 23 раз
# В заказе на "Чудовище в пещере"(0) встречается 21 раз
#
# ==================================================
#
# Запись в дневнике   Роль
# выследить цель      следопыт       85
# залечить раны       лекарь        121
# найти пропажу       следопыт      148
# отыскать заказчика  следопыт      148
# разжечь костёр      мечник        172
#                     рейнджер      115
#                     лучник         55
#                     боевой маг     44
# Name: count, dtype: int64

# %%
class_to_role
# Out:
# {0: ['лекарь', 'лучник', 'мечник', 'боевой маг'],
#  1: ['следопыт'],
#  2: ['следопыт'],
#  3: ['рейнджер', 'следопыт', 'лекарь', 'лучник', 'мечник', 'боевой маг']}

# %% [markdown]
# Средние оценки героев по всем поручениям:

# %%
heroes = marks['Герой'].unique()
print(heroes)
# Out:
# ['Мартин' 'Альфред' 'Бендер' 'Юлия' 'Агата' 'Фредерик' 'Пастушок' 'Соня'
#  'Леопольд' 'Глюкоза' 'Бенедикт' 'Синеглазый']

# %%
marks[['Герой','Оценка за качество','Оценка по срокам','Оценка за вежливость']].groupby('Герой').mean()
# Out:
#             Оценка за качество  Оценка по срокам  Оценка за вежливость
# Герой
# Агата                 3.939394          3.727273              4.000000
# Альфред               3.871795          3.692308              3.897436
# Бендер                3.928571          3.928571              3.928571
# Бенедикт              3.785714          3.880952              3.928571
# Глюкоза               3.863636          3.931818              4.000000
# Леопольд              3.893617          3.808511              3.872340
# Мартин                3.967742          3.935484              3.935484
# Пастушок              4.000000          3.836735              4.000000
# Синеглазый            3.878049          3.756098              3.878049
# Соня                  3.888889          3.972222              3.833333
# Фредерик              3.878049          4.000000              3.878049
# Юлия                  3.818182          3.672727              3.945455

# %% [markdown]
# Количество записей в дневких для каждой роли героя

# %%
note_cnt = diaries[['Герой', 'Роль', 'Запись в дневнике']].groupby('Герой').value_counts()
for hero in heroes:
    print(hero)
    print(note_cnt[hero])
    print()
# Out:
# Мартин
# Роль      Запись в дневнике
# лучник    разжечь костёр        15
# следопыт  отыскать заказчика    14
#           найти пропажу         14
# лекарь    залечить раны          8
# рейнджер  разжечь костёр         8
# следопыт  выследить цель         3
# Name: count, dtype: int64
#
# Альфред
# Роль      Запись в дневнике
# мечник    разжечь костёр        26
# лекарь    залечить раны         22
# рейнджер  разжечь костёр        13
# следопыт  выследить цель         8
#           найти пропажу          6
#           отыскать заказчика     6
# Name: count, dtype: int64
#
# Бендер
# Роль      Запись в дневнике
# мечник    разжечь костёр        22
# следопыт  найти пропажу         15
#           отыскать заказчика    15
#           выследить цель         7
# рейнджер  разжечь костёр         6
# Name: count, dtype: int64
#
# Юлия
# Роль      Запись в дневнике
# мечник    разжечь костёр        33
# лекарь    залечить раны         23
# рейнджер  разжечь костёр        18
# следопыт  отыскать заказчика    13
#           найти пропажу         13
#           выследить цель        11
# Name: count, dtype: int64
#
# Агата
# Роль      Запись в дневнике
# лучник    разжечь костёр        17
# следопыт  найти пропажу          9
#           отыскать заказчика     9
# рейнджер  разжечь костёр         7
# следопыт  выследить цель         6
# Name: count, dtype: int64
#
# Фредерик
# Роль      Запись в дневнике
# лучник    разжечь костёр        23
# лекарь    залечить раны         19
# следопыт  найти пропажу         16
#           отыскать заказчика    16
# рейнджер  разжечь костёр         7
# следопыт  выследить цель         5
# Name: count, dtype: int64
#
# Пастушок
# Роль      Запись в дневнике
# мечник    разжечь костёр        22
# следопыт  отыскать заказчика    15
#           найти пропажу         15
#           выследить цель         9
# рейнджер  разжечь костёр         8
# Name: count, dtype: int64
#
# Соня
# Роль        Запись в дневнике
# боевой маг  разжечь костёр        19
# лекарь      залечить раны         15
# следопыт    отыскать заказчика    11
#             найти пропажу         11
#             выследить цель         7
# рейнджер    разжечь костёр         7
# Name: count, dtype: int64
#
# Леопольд
# Роль      Запись в дневнике
# мечник    разжечь костёр        25
# следопыт  найти пропажу         14
#           отыскать заказчика    14
# рейнджер  разжечь костёр        12
# следопыт  выследить цель         8
# Name: count, dtype: int64
#
# Глюкоза
# Роль        Запись в дневнике
# боевой маг  разжечь костёр        25
# следопыт    отыскать заказчика    12
#             найти пропажу         12
# рейнджер    разжечь костёр         9
# следопыт    выследить цель         8
# Name: count, dtype: int64
#
# Бенедикт
# Роль      Запись в дневнике
# мечник    разжечь костёр        23
# лекарь    залечить раны         16
# следопыт  отыскать заказчика    12
#           найти пропажу         12
# рейнджер  разжечь костёр        10
# следопыт  выследить цель         6
# Name: count, dtype: int64
#
# Синеглазый
# Роль      Запись в дневнике
# мечник    разжечь костёр        21
# лекарь    залечить раны         18
# следопыт  отыскать заказчика    11
#           найти пропажу         11
# рейнджер  разжечь костёр        10
# следопыт  выследить цель         7
# Name: count, dtype: int64

# %% [markdown]
# ### Формирование датасета со статистикой оценок/времени/суммы по героям

# %%
diaries_edited = pd.merge(diaries, marks, on=['Номер поручения', 'Герой'], how='left')
diaries_edited = pd.merge(diaries_edited, cases[['Номер поручения', 'Тип поручения', 'Затрачено дней', 'Сумма вознаграждения']], on=['Номер поручения'], how='left')

# %%
stats = diaries_edited[['Герой', 'Тип поручения', 'Роль', 'Оценка за качество', 'Оценка по срокам', 'Оценка за вежливость', 'Затрачено часов', 'Затрачено дней', 'Сумма вознаграждения']].groupby(['Герой', 'Тип поручения', 'Роль']).mean()
stats['Количество поручений'] = diaries_edited[['Герой', 'Тип поручения', 'Роль']].groupby(['Герой', 'Тип поручения', 'Роль']).value_counts()
stats
# Out:
#                               Оценка за качество  Оценка по срокам  \
# Герой Тип поручения Роль
# Агата 0             лучник              4.125000          4.375000
#       1             следопыт            4.000000          3.500000
#       2             следопыт            3.777778          3.777778
#       3             лучник              3.888889          3.111111
#                     рейнджер            3.857143          3.000000
# ...                                          ...               ...
# Юлия  2             следопыт            3.923077          3.615385
#       3             лекарь              3.833333          3.750000
#                     мечник              3.818182          3.772727
#                     рейнджер            3.833333          3.888889
#                     следопыт            4.000000          4.200000
#
#                               Оценка за вежливость  Затрачено часов  \
# Герой Тип поручения Роль
# Агата 0             лучник                4.125000         0.666667
#       1             следопыт              3.500000         4.000000
#       2             следопыт              4.000000         2.500000
#       3             лучник                4.222222         0.666667
#                     рейнджер              4.000000         2.000000
# ...                                            ...              ...
# Юлия  2             следопыт              3.846154         3.750000
#       3             лекарь                4.083333        18.000000
#                     мечник                4.045455         1.000000
#                     рейнджер              4.055556         0.666667
#                     следопыт              3.800000         6.000000
#
#                               Затрачено дней  Сумма вознаграждения  \
# Герой Тип поручения Роль
# Агата 0             лучник          4.250000          16000.000000
#       1             следопыт        6.250000          15500.000000
#       2             следопыт        5.555556          16944.444444
#       3             лучник          5.222222           8888.888889
#                     рейнджер        4.714286           8642.857143
# ...                                      ...                   ...
# Юлия  2             следопыт        6.230769          15653.846154
#       3             лекарь          6.666667          14041.666667
#                     мечник          6.318182          14863.636364
#                     рейнджер        6.944444          15861.111111
#                     следопыт        6.800000          18400.000000
#
#                               Количество поручений
# Герой Тип поручения Роль
# Агата 0             лучник                       8
#       1             следопыт                     4
#       2             следопыт                    18
#       3             лучник                       9
#                     рейнджер                     7
# ...                                            ...
# Юлия  2             следопыт                    26
#       3             лекарь                      12
#                     мечник                      22
#                     рейнджер                    18
#                     следопыт                     5
#
# [86 rows x 7 columns]

# %%
stats.to_csv('../data/stats.csv')
